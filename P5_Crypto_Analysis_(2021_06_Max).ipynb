# %% [markdown]
# <a href="https://colab.research.google.com/github/nilradi/DS-Projects/blob/main/P5_Crypto_Analysis_(2021_06_Max).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use('fivethirtyeight')
# %matplotlib inline
import matplotlib
from matplotlib.colors import LinearSegmentedColormap

from pandas_datareader.data import DataReader

from datetime import datetime

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importamos BTC Data

# %%
dataparse = lambda dates: pd.datetime.strptime(dates, '%d-%m-%Y')
btc = pd.read_csv('/content/drive/MyDrive/proyectos/P5/cryptodata/Bitcoin.csv', parse_dates = ['Date'], index_col = 'Date', date_parser = dataparse)
btc.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-06-27  32287.523211  34656.127356  32071.757148  34649.644588
# 2021-06-26  31594.663571  32637.587193  30184.501794  32186.277671
# 2021-06-25  34659.104499  35487.248003  31350.883858  31637.780055
# 2021-06-24  33682.800404  35228.852611  32385.214696  34662.435894
# 2021-06-23  32515.714303  34753.408503  31772.632355  33723.028978
#
#                   Volume    Market Cap
# Date
# 2021-06-27  3.551164e+10  6.494617e+11
# 2021-06-26  3.858539e+10  6.032760e+11
# 2021-06-25  4.023090e+10  5.929782e+11
# 2021-06-24  3.312337e+10  6.496440e+11
# 2021-06-23  4.631711e+10  6.320113e+11

# %%
btc = btc.iloc[::-1]
btc.head(5)
# Out:
#                   Open        High         Low       Close  Volume  \
# Date
# 2013-04-28  135.300003  135.979996  132.100006  134.210007     0.0
# 2013-04-29  134.444000  147.488007  134.000000  144.539993     0.0
# 2013-04-30  144.000000  146.929993  134.050003  139.000000     0.0
# 2013-05-01  139.000000  139.889999  107.720001  116.989998     0.0
# 2013-05-02  116.379997  125.599998   92.281898  105.209999     0.0
#
#               Market Cap
# Date
# 2013-04-28  1.488567e+09
# 2013-04-29  1.603769e+09
# 2013-04-30  1.542813e+09
# 2013-05-01  1.298955e+09
# 2013-05-02  1.168517e+09

# %%
maxValue = btc[btc['Close']== max(btc.Close)]
print('Highiest value of BTC')
maxValue
# Out:
# Highiest value of BTC
#                    Open          High           Low        Close  \
# Date
# 2021-04-13  59890.01779  63742.283337  59869.956293  63503.45793
#
#                   Volume    Market Cap
# Date
# 2021-04-13  6.998345e+10  1.186364e+12

# %%
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2983 entries, 2013-04-28 to 2021-06-27
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Open        2983 non-null   float64
#  1   High        2983 non-null   float64
#  2   Low         2983 non-null   float64
#  3   Close       2983 non-null   float64
#  4   Volume      2983 non-null   float64
#  5   Market Cap  2983 non-null   float64
# dtypes: float64(6)
# memory usage: 163.1 KB

# %%
btc.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count   2983.000000   2983.000000   2983.000000   2983.000000  2.983000e+03
# mean    6613.843852   6805.260516   6402.037782   6625.160672  1.084006e+10
# std    11199.197921  11553.544329  10781.352553  11209.848478  1.887826e+10
# min       68.504997     74.561096     65.526001     68.431000  0.000000e+00
# 25%      429.792999    435.968491    421.852005    429.862000  3.013725e+07
# 50%     2191.560059   2303.899902   2071.989990   2202.419922  9.174120e+08
# 75%     8494.818022   8687.633944   8230.187652   8500.334961  1.575577e+10
# max    63523.754869  64863.098908  62208.964366  63503.457930  3.509679e+11
#
#          Market Cap
# count  2.983000e+03
# mean   1.192478e+11
# std    2.092413e+11
# min    7.784112e+08
# 25%    6.294347e+09
# 50%    3.601766e+10
# 75%    1.488823e+11
# max    1.186364e+12

# %% [markdown]
# ## Importamos DogeCoin Data

# %%
doge = pd.read_csv('/content/drive/MyDrive/proyectos/P5/cryptodata/Meme Coin/Dogecoin.csv', parse_dates = ['Date'], index_col = 'Date', date_parser = dataparse)

# %%
doge = doge.iloc[::-1]
doge.tail(5)
# Out:
#                 Open      High       Low     Close        Volume    Market Cap
# Date
# 2021-06-23  0.190671  0.247110  0.180979  0.232174  5.098675e+09  3.021735e+10
# 2021-06-24  0.234970  0.268690  0.222527  0.262782  3.844648e+09  3.420559e+10
# 2021-06-25  0.263480  0.289145  0.230006  0.239153  5.542163e+09  3.113117e+10
# 2021-06-26  0.237673  0.255127  0.230972  0.244784  2.649457e+09  3.186753e+10
# 2021-06-27  0.246045  0.266891  0.240894  0.264450  2.167522e+09  3.443160e+10

# %%
maxValue = doge[doge['Close']== max(doge.Close)]
print('Highiest value of Doge')
maxValue
# Out:
# Highiest value of Doge
#                Open      High       Low     Close        Volume    Market Cap
# Date
# 2021-05-07  0.58111  0.731972  0.520174  0.684777  2.861508e+10  8.868082e+10

# %% [markdown]
# ## Importamos Bitconnect Data

# %%
bit = pd.read_csv('/content/drive/MyDrive/proyectos/P5/cryptodata/Dead Coin/bitconnect.csv', parse_dates=['Date'], index_col='Date', date_parser= dataparse)

# %%
bit=bit.iloc[:,1:7]
bit = bit.iloc[::-1]
bit=bit.iloc[:1580]
bit18=bit[:609]
bit.tail(5)
# Out:
#             Open  High   Low  Close  Volume  Volume(BCC)
# Date
# 2021-05-16  2.40  2.48  2.14   2.25    0.00         0.00
# 2021-05-17  2.25  2.30  2.06   2.19    4.26         1.92
# 2021-05-18  2.19  2.50  2.18   2.32   18.81         8.01
# 2021-05-19  2.31  2.34  1.68   2.01    0.00         0.00
# 2021-05-20  2.01  2.28  1.91   2.19    0.00         0.00

# %%
maxValue=bit[bit['Close']==max(bit.Close)]
print("Highiest value of Bitconnect")
maxValue
# Out:
# Highiest value of Bitconnect
#               Open    High    Low   Close      Volume  Volume(BCC)
# Date
# 2017-12-31  413.53  470.86  407.8  463.31  41366100.0     94254.86

# %% [markdown]
# ## Importing Ethereum Data

# %%
eth=pd.read_csv('/content/drive/MyDrive/proyectos/P5/cryptodata/Ethereum.csv',parse_dates=['Date'],index_col='Date', date_parser=dataparse)
eth = eth.iloc[::-1]
eth.tail(5)
# Out:
#                    Open         High          Low        Close        Volume  \
# Date
# 2021-06-23  1878.625034  2043.530443  1827.571482  1989.736271  2.840866e+10
# 2021-06-24  1968.957423  2032.339389  1887.432046  1988.456276  2.027285e+10
# 2021-06-25  1989.215789  2017.759464  1794.400424  1813.217232  2.277433e+10
# 2021-06-26  1810.884253  1850.179779  1719.559464  1829.239217  2.063754e+10
# 2021-06-27  1830.996918  1979.958125  1811.245864  1978.894662  1.988547e+10
#
#               Market Cap
# Date
# 2021-06-23  2.316253e+11
# 2021-06-24  2.315093e+11
# 2021-06-25  2.111311e+11
# 2021-06-26  2.130212e+11
# 2021-06-27  2.304736e+11

# %%
maxValue=eth[eth['Close']==max(eth.Close)]
print("Highiest value of Bitconnect")
maxValue
# Out:
# Highiest value of Bitconnect
#                    Open         High          Low        Close        Volume  \
# Date
# 2021-05-11  3948.271909  4178.208815  3783.889474  4168.701049  5.267974e+10
#
#               Market Cap
# Date
# 2021-05-11  4.828819e+11

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Precio de cierre de varias cryptos en 2018 vs 2020

# %%
def to2018(df):
  df18 = equalize(df,bit)
  return df18.iloc[:len(bit18)]

def equalize(df, dfs):
  low = len(dfs)
  high = len(df)
  dff = high - low

  return df.iloc[dff:]

# %%
btc18=to2018(btc)
eth18=to2018(eth)
crypto=["Bitcoin 2018","Bitcoin","Ethereum 2018","Ethereum","Bitconnect 2018","Dogecoin"]
cryptoDf=[btc18,btc,eth18,eth,bit18,doge]
num_plots = 6
total_cols = 2
total_rows = 3
fig, axs = plt.subplots(nrows=total_rows, ncols=total_cols,
                        figsize=(14*total_cols, 7*total_rows), constrained_layout=True)
for i, var in enumerate(crypto):
    row = i//total_cols
    pos = i % total_cols
    sns.set_context('paper', font_scale = 2)
    plot =  sns.lineplot(data=cryptoDf[i], x="Date", y="Close",color='#732C2C',palette ='coolwarm',ax=axs[row][pos])
    axs[row][pos].set_title(crypto[i])

# %% [markdown]
# ### Podemos ver que en 2018 hubo un pico en todas las divisas y empezó a caer después. Lo que es muy similar a algo que sucedió en 2021? Hay un tipo de pico similar en todas las monedas. Pero también podemos ver que bitconnect cayó drásticamente y dejó de existir después de eso. Mientras que Bitcoin y Ethereum sobrevivieron al impacto y siguen en el mercado

# %% [markdown]
# ## Volumen de varias criptos en 2018 frente a 2020
# ### El volumen, como se entiende en el sentido general, se cuenta como el número total. Aquí, en la terminología del mercado de criptomonedas, se mide como el número de monedas que se negocian (compradas y vendidas) durante el período de negociación, es decir, dentro de un período determinado. En el caso de los gráficos anteriores, el periodo es de un solo día.

# %%
fig, axs = plt.subplots(nrows=total_rows, ncols=total_cols,
                        figsize=(14*total_cols, 7*total_rows), constrained_layout=True)
for i, var in enumerate(crypto):
    row = i//total_cols
    pos = i % total_cols
    sns.set_context('paper', font_scale = 2)
    plot =  sns.lineplot(data=cryptoDf[i], x="Date", y="Volume",color='#732C2C',palette ='coolwarm',ax=axs[row][pos])
    axs[row][pos].set_title(crypto[i])

# %% [markdown]
# ###Podemos observar tanto en los gráficos de precios como en los de volumen. Que el precio de bitconnect era demasiado dependiente del volumen de monedas. Como cada pico de volumen en los gráficos de bitconnect muestra un aumento en el precio. También, la caída cuando hubo un gran pico en el volumen de bitconnect podemos decir que cuando el precio empezó a caer en el mercado de criptomonedas la gente empezó a vender más y más lo que causó un gran pico en el volumen y como bitconnect era tan dependiente del volumen se estrelló. Bitcoin y Ethereum fueron capaces de mantener esta caída en el precio porque también dependen de otros factores.

# %% [markdown]
# ## Rentabilidad
#
# ### La rentabilidad en el mercado de criptomonedas no es más que la variación porcentual del precio

# %%
for df in cryptoDf:
    df['Daily Return'] = df['Close'].pct_change()
fig, axs = plt.subplots(nrows=total_rows, ncols=total_cols,
                        figsize=(14*total_cols, 7*total_rows), constrained_layout=True)
for i, var in enumerate(crypto):
    row = i//total_cols
    pos = i % total_cols
    cryptoDf[i]['Daily Return'].plot(ax=axs[row][pos], legend=True,color='#732C2C', linestyle='--', marker='.')
    axs[row][pos].set_title(crypto[i])

# %%
fig, axs = plt.subplots(nrows=total_rows, ncols=total_cols,
                        figsize=(8*total_cols, 5*total_rows))
for i, var in enumerate(crypto):
    row = i//total_cols
    pos = i % total_cols
    plot =sns.distplot(cryptoDf[i]['Daily Return'], bins=100, color='#732C2C',ax=axs[row][pos])
    axs[row][pos].set_title(crypto[i])
    plt.ylabel('Daily Return')

plt.tight_layout()

# %% [markdown]
# ## Correlación
#
# ### Para la correlación necesitaremos un conjunto de datos del precio de cierre de todas las criptomonedas de nuestra lista. Por lo tanto, haremos dos conjuntos de datos, uno para 2018 y otro para 2021.

# %%
closeDf18=pd.DataFrame()
closeDf18['btc']=btc18['Close']
closeDf18['eth']=eth18['Close']
closeDf18['bit']=bit18['Close']
returns18 = closeDf18.pct_change()
returns18.head()
# Out:
#                  btc       eth       bit
# Date
# 2017-03-01       NaN       NaN       NaN
# 2017-03-02  0.023321  0.096860 -0.000918
# 2017-03-03  0.019168  0.022533  0.047246
# 2017-03-04 -0.015561 -0.043173  0.009345
# 2017-03-05  0.009537  0.036705  0.029484

# %%
btc=equalize(btc,eth)
doge=equalize(doge,eth)
closeDf=pd.DataFrame()
closeDf['btc']=btc['Close']
closeDf['eth']=eth['Close']
closeDf['doge']=doge['Close']
returns = closeDf.pct_change()
returns.head()
# Out:
#                  btc       eth      doge
# Date
# 2015-08-07       NaN       NaN       NaN
# 2015-08-08 -0.066484 -0.728250 -0.059557
# 2015-08-09  0.015655 -0.068268  0.022199
# 2015-08-10 -0.002313  0.009333 -0.010966
# 2015-08-11  0.022369  0.507323  0.022920

# %% [markdown]
# ## Ahora podemos comparar el porcentaje de retorno diario de dos criptos para comprobar su correlación.

# %%
sns.jointplot(data=returns18, x='btc', y="bit", kind='scatter',color='#732C2C',height=8)
plt.show()

# %%
sns.jointplot(data=returns, x='btc', y="doge", kind='scatter',color='#732C2C',height=8)
plt.show()

# %% [markdown]
# ### Creación de un mapa de colores personalizado para el mapa de calor.

# %%
def NonLinCdict(steps, hexcol_array):
    cdict = {'red': (), 'green': (), 'blue': ()}
    for s, hexcol in zip(steps, hexcol_array):
        rgb =matplotlib.colors.hex2color(hexcol)
        cdict['red'] = cdict['red'] + ((s, rgb[0], rgb[0]),)
        cdict['green'] = cdict['green'] + ((s, rgb[1], rgb[1]),)
        cdict['blue'] = cdict['blue'] + ((s, rgb[2], rgb[2]),)
    return cdict

hc = ['#F8EDED', '#EAC8C8', '#CF7F7F', '#BA4949', '#732C2C']
th = [0, 0.1, 0.5, 0.9, 1]

cdict = NonLinCdict(th, hc)
cm = LinearSegmentedColormap('test', cdict)
plt.figure(figsize=(10,6))
sns.heatmap(returns18.corr(), annot=True, cmap=cm)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(returns.corr(), annot=True, cmap=cm)
plt.show()

# %%
rets = returns18.dropna()

area = np.pi * 20

plt.figure(figsize=(10, 7))
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(label, xy=(x, y), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom', 
                 arrowprops=dict(arrowstyle='-', color='#732C2C', connectionstyle='arc3,rad=-0.3'))

# %% [markdown]
# ### En este gráfico podemos ver claramente que aunque bitconnect tenía una rentabilidad muy alta en comparación con bitcoin o Ethereum, era muy arriesgado invertir dinero en ello

# %%
rets = returns.dropna()

area = np.pi * 20

plt.figure(figsize=(10, 7))
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(label, xy=(x, y), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom', 
                 arrowprops=dict(arrowstyle='-', color='#732C2C', connectionstyle='arc3,rad=-0.3'))

# %% [markdown]
# ### Aquí podemos ver que dogecoin también es tan arriesgado como Bitconnect en el pasado.

# %% [markdown]
# ## Conclusión
#
# ### Podemos concluir las respuestas a la pregunta más famosa. ¿Es Dogecoin un nuevo Bitcoin? o ¿Dogecoin sustituirá a Bitcoin alguna vez? La respuesta es: no. A partir de los gráficos podemos ver claramente que Ethereum, y Bitcoin son bastante más seguros que Dogecoin y Bitconnect. Por lo que están sobreviviendo a la caída en 2018 y sobrevivirán a través de la caída actual en el precio también. La caída de Dogecoin es inevitable. Aunque Dogecoin no es una estafa. Pero la estructura cultural de dogecoin cava una tumba para sí mismo. Invierta su dinero sabiamente después de hacer su propia investigación.
